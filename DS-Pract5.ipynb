# %% [markdown]
# ### Perform Mutltivariate Linear regression

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\abdul shaikh\documents\anaconda\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\abdul shaikh\documents\anaconda\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\abdul shaikh\documents\anaconda\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\abdul shaikh\documents\anaconda\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\abdul shaikh\documents\anaconda\lib\site-packages (from scikit-learn) (3.5.0)

# %%
import sklearn

# %%
boston_df = pd.read_csv("Boston.csv")

# %%
boston_df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
boston_df = boston_df.drop("Unnamed: 0",axis = 1)

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston_x = pd.DataFrame(boston_df.iloc[:,:13])

# %%
boston_y = pd.DataFrame(boston_df.iloc[:,-1])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(boston_x,boston_y,test_size=0.3)

# %%
print(f'X Train Size: {X_train.shape}')
print(f'X Test Size: {X_test.shape}')
print(f'Y Train Size: {Y_train.shape}')
print(f'Y Test Size: {Y_test.shape}')
# Out:
# X Train Size: (354, 13)
# X Test Size: (152, 13)
# Y Train Size: (354, 1)
# Y Test Size: (152, 1)

# %%
from sklearn.linear_model import LinearRegression
reg_model = LinearRegression()
reg_model.fit(X_train,Y_train)
y_predicted = reg_model.predict(X_test)

# %%
Y_pred = pd.DataFrame(y_predicted,columns=["Predicted_Y"])
Y_pred.head()
# Out:
#    Predicted_Y
# 0    24.401654
# 1    13.887498
# 2    24.837434
# 3    28.125129
# 4    23.138483

# %%
plt.scatter(Y_test,Y_pred,c="green")
plt.xlabel("Actual Price(medv)")
plt.ylabel("Predicted Price")
plt.show()
