# %% [markdown]
# ### Perfrom Decison Tree on train.csv

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# %%
titanic_df=pd.read_csv("train.csv")
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
features=['Pclass','Sex','Age','SibSp','Parch']
x=titanic_df[features]
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    object
#  2   Age     714 non-null    float64
#  3   SibSp   891 non-null    int64
#  4   Parch   891 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 34.9+ KB

# %%
Y=titanic_df['Survived']
Y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int64
# dtypes: int64(1)
# memory usage: 7.1 KB

# %%
x['Sex']=x['Sex'].map({'male':0,'female':1})
x.head()
# Out:
# C:\temp\ipykernel_25804\498787313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Sex']=x['Sex'].map({'male':0,'female':1})
#    Pclass  Sex   Age  SibSp  Parch
# 0       3    0  22.0      1      0
# 1       1    1  38.0      1      0
# 2       3    1  26.0      0      0
# 3       1    1  35.0      1      0
# 4       3    0  35.0      0      0

# %%
x['Age'].fillna(x['Age'].median(),inplace=True)
# Out:
# C:\temp\ipykernel_25804\2799591518.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x['Age'].fillna(x['Age'].median(),inplace=True)
# C:\temp\ipykernel_25804\2799591518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Age'].fillna(x['Age'].median(),inplace=True)

# %%
x.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,Y,test_size=0.2,random_state=10)

# %%
dtmodel=DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=10)

dtmodel.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=10)

# %%
Y_pred=dtmodel.predict(X_test)

# %%
print("Accuracy: ",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy:  0.8379888268156425

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       117
#            1       0.77      0.76      0.76        62
#
#     accuracy                           0.84       179
#    macro avg       0.82      0.82      0.82       179
# weighted avg       0.84      0.84      0.84       179

# %%
plt.figure(figsize=(18,10))
plot_tree(dtmodel,feature_names=features,class_names=['Not Survived','Survived'],filled=True)
# Out:
# [Text(0.5, 0.9, 'Sex <= 0.5\nentropy = 0.967\nsamples = 712\nvalue = [432, 280]\nclass = Not Survived'),
#  Text(0.25, 0.7, 'Pclass <= 1.5\nentropy = 0.718\nsamples = 454\nvalue = [364, 90]\nclass = Not Survived'),
#  Text(0.375, 0.8, 'True  '),
#  Text(0.125, 0.5, 'Age <= 60.5\nentropy = 0.949\nsamples = 98\nvalue = [62, 36]\nclass = Not Survived'),
#  Text(0.0625, 0.3, 'Age <= 17.5\nentropy = 0.972\nsamples = 87\nvalue = [52.0, 35.0]\nclass = Not Survived'),
#  Text(0.03125, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.09375, 0.1, 'entropy = 0.968\nsamples = 86\nvalue = [52, 34]\nclass = Not Survived'),
#  Text(0.1875, 0.3, 'Age <= 75.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]\nclass = Not Survived'),
#  Text(0.15625, 0.1, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Not Survived'),
#  Text(0.21875, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.375, 0.5, 'Age <= 13.0\nentropy = 0.614\nsamples = 356\nvalue = [302, 54]\nclass = Not Survived'),
#  Text(0.3125, 0.3, 'SibSp <= 2.5\nentropy = 0.999\nsamples = 25\nvalue = [12, 13]\nclass = Survived'),
#  Text(0.28125, 0.1, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Survived'),
#  Text(0.34375, 0.1, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Not Survived'),
#  Text(0.4375, 0.3, 'Parch <= 1.5\nentropy = 0.54\nsamples = 331\nvalue = [290, 41]\nclass = Not Survived'),
#  Text(0.40625, 0.1, 'entropy = 0.554\nsamples = 318\nvalue = [277, 41]\nclass = Not Survived'),
#  Text(0.46875, 0.1, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Not Survived'),
#  Text(0.75, 0.7, 'Pclass <= 2.5\nentropy = 0.832\nsamples = 258\nvalue = [68, 190]\nclass = Survived'),
#  Text(0.625, 0.8, '  False'),
#  Text(0.625, 0.5, 'Age <= 3.0\nentropy = 0.321\nsamples = 137\nvalue = [8, 129]\nclass = Survived'),
#  Text(0.5625, 0.3, 'Parch <= 1.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.53125, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.59375, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.6875, 0.3, 'Pclass <= 1.5\nentropy = 0.294\nsamples = 135\nvalue = [7, 128]\nclass = Survived'),
#  Text(0.65625, 0.1, 'entropy = 0.107\nsamples = 71\nvalue = [1, 70]\nclass = Survived'),
#  Text(0.71875, 0.1, 'entropy = 0.449\nsamples = 64\nvalue = [6, 58]\nclass = Survived'),
#  Text(0.875, 0.5, 'SibSp <= 2.5\nentropy = 1.0\nsamples = 121\nvalue = [60, 61]\nclass = Survived'),
#  Text(0.8125, 0.3, 'Age <= 38.5\nentropy = 0.985\nsamples = 105\nvalue = [45, 60]\nclass = Survived'),
#  Text(0.78125, 0.1, 'entropy = 0.947\nsamples = 93\nvalue = [34, 59]\nclass = Survived'),
#  Text(0.84375, 0.1, 'entropy = 0.414\nsamples = 12\nvalue = [11, 1]\nclass = Not Survived'),
#  Text(0.9375, 0.3, 'Age <= 5.5\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]\nclass = Not Survived'),
#  Text(0.90625, 0.1, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Not Survived'),
#  Text(0.96875, 0.1, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Not Survived')]
